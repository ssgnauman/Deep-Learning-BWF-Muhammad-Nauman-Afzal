# %% [markdown]
# # 🔴 Task 24
#
# Topics: Data Preprocessing and Feature Engineering
#
# Resource: https://drive.google.com/file/d/1i9dPxM_1M4HYN5bYxFcuklC1vM0GrOCq/view?usp=share_link

# %% [markdown]
# # Definations / Introductions
# ![image.png](attachment:image.png)

# %% [markdown]
# # Difference
# ![image.png](attachment:image.png)

# %% [markdown]
# # Techniques to Find
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Examples

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Sample dataset
data = {'Age': [25, 32, 44, 23, 36, 52],
        'Income': [40000, 55000, 70000, 30000, 65000, 80000],
        'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
        'Purchased': [0, 1, 1, 0, 1, 1]}

# %%
df = pd.DataFrame(data)

# %%
# Data Preprocessing
# Standardize the income column
scaler = StandardScaler()
df['Income'] = scaler.fit_transform(df[['Income']])

# %%
# Feature Engineering
# One-hot encode the gender column
df = pd.get_dummies(df)

# %%
print(df)
# Out:
#    Age    Income  Purchased  Gender_Female  Gender_Male
# 0   25 -0.966736          0              0            1
# 1   32 -0.096674          1              1            0
# 2   44  0.773389          1              0            1
# 3   23 -1.546778          0              1            0
# 4   36  0.483368          1              0            1
# 5   52  1.353431          1              1            0

# %%
...........................End..............................
