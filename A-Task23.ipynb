# %% [markdown]
# # 🔴 Task 23
#
# Topics: Dataset Loading and Understanding Training, Validation and Test Sets
#
# Resource:https://drive.google.com/file/d/1i9dPxM_1M4HYN5bYxFcuklC1vM0GrOCq/view?usp=share_link
#
# This is a very important concept theoretically and it's implementation is also present in detail in the resource. Splitting data is a good proportion of subsets is critical

# %% [markdown]
# # Dataset Loading and Understanding:

# %% [markdown]
# <small>Dataset Loading and Understanding: In machine learning, a dataset is a collection of data that is used to train and test a model. Datasets can come in many different formats, such as CSV files, Excel spreadsheets, or databases. To use a dataset in a machine learning project, you first need to load it into your program. This can be done using various libraries and tools depending on the format of the dataset. Once the dataset is loaded, it’s important to understand its contents and structure. This includes knowing the number of rows and columns, the types of data in each column, and any missing or invalid values.</small>

# %%
import pandas as pd

# %%
# Load the dataset from a URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
data = pd.read_csv(url)

# %%
# Display the first five rows of data
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Easy and simple method to load Multiple CSv files in a DataFrame

# %%
import pandas as pd
import glob

# %%
# Read all the files into a single DataFrame
data = pd.concat([pd.read_csv(file) for file in glob.glob('states*.csv')])

# %%
# Display the first five rows of data
print(data.head())
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
import pandas as pd

# Create an empty DataFrame to store the data
data = pd.DataFrame()

# Loop over the file numbers
for i in range(10):
    # Generate the file name
    file = 'states{}.csv'.format(i)
    
    # Read the file into a DataFrame
    df = pd.read_csv(file)
    
    # Append the data to the main DataFrame
    data = data.append(df)

# Display the first five rows of data
print(data.head())
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
import pandas as pd

# Generate the list of file names
files = ['states{}.csv'.format(i) for i in range(10)]

# Read all the files into a single DataFrame
data = pd.concat([pd.read_csv(file) for file in files])

# Display the first five rows of data
print(data.head())
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %% [markdown]
# # example of how you can load the titanic dataset from the seaborn library and save it to different file formats using the pandas library:

# %%
import seaborn as sns
import pandas as pd

# %%
data = sns.load_dataset('titanic')

# %%
# Save to CSV file
data.to_csv('titanic.csv', index=False)

# %%
# Save to Excel file
data.to_excel('titanic.xlsx', index=False, sheet_name='Sheet1')

# %%
# Save to JSON file
data.to_json('titanic.json', orient='records')

# %%
# Display the first 5 rows of the data
print(data.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd

# Load data from CSV file
data_csv = pd.read_csv('titanic.csv')

# Display the first 5 rows of the data
print('Data from CSV file:')
print(data_csv.head())
# Out:
# Data from CSV file:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Load data from Excel file
data_excel = pd.read_excel('titanic.xlsx', sheet_name='Sheet1')

# Display the first 5 rows of the data
print('Data from Excel file:')
print(data_excel.head())
# Out:
# Data from Excel file:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Load data from JSON file
data_json = pd.read_json('titanic.json')

# Display the first 5 rows of the data
print('Data from JSON file:')
print(data_json.head())
# Out:
# Data from JSON file:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man        True  None  Southampton    no  False
# 1  woman       False     C    Cherbourg   yes  False
# 2  woman       False  None  Southampton   yes   True
# 3  woman       False     C  Southampton   yes  False
# 4    man        True  None  Southampton    no   True

# %% [markdown]
# # Understanding Training, Validation and Test Sets

# %% [markdown]
# <small>When teaching a computer using machine learning, you need to give it data to learn from. This data is called a dataset. To make sure the computer is learning well, you split the dataset into three parts: a training set, a validation set, and a test set.
#
# The training set is used to teach the computer. The computer looks at this data and tries to learn from it.
#
# The validation set is used to check how well the computer is learning. You show the computer this data and see if it can make good predictions. If the computer is not doing well, you can make changes to help it learn better.
#
# The test set is used to see how well the computer can use what it learned on new data. You show the computer this data after it has finished learning. This helps you see if the computer can make good predictions on data it has never seen before.
#
# Splitting the data like this helps you make sure that the computer is really learning and not just memorizing the answers</small>

# %% [markdown]
# # Overfitting

# %% [markdown]
# <small>Overfitting is when a machine learning model is too complex and memorizes the training data instead of learning to generalize from it. This means that the model will do very well on the training data, but it will not do well on new data that it has never seen before.
#
# Think of it like studying for a test. If you memorize all the answers to the practice questions, you will do very well on the practice test. But if the real test has different questions, you will not do well because you didn’t learn how to solve the problems, you just memorized the answers.
#
# To avoid overfitting, you can use techniques like simplifying the model or using a validation set to check how well the model is learning.</small>

# %% [markdown]
# # example of how you can split a dataset into training, validation, and test sets using the train_test_split function from the scikit-learn library in Python:

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# Load sample data
iris = load_iris()
X, y = iris.data, iris.target

# %%
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Split training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Create a random forest classifier
clf = RandomForestClassifier()

# Train the model using the training set
clf.fit(X_train, y_train)

# Make predictions on the validation set
y_pred = clf.predict(X_val)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_val, y_pred)

# Print the accuracy
print(f'Validation accuracy: {accuracy:.2f}')
# Out:
# Validation accuracy: 0.92

# %% [markdown]
# <small>! Here’s a step-by-step explanation of the code you provided:
#
# First, the necessary libraries are imported. load_iris is used to load a sample dataset, train_test_split is used to split the data into training, validation, and test sets, RandomForestClassifier is used to create a machine learning model, and accuracy_score is used to calculate the accuracy of the model.
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score
# Next, the iris dataset is loaded from the scikit-learn library and split into features X and target variable y.
# # Load sample data
# iris = load_iris()
# X, y = iris.data, iris.target
# The data is then split into training and test sets using the train_test_split function with a test size of 20%. The training data is further split into training and validation sets with a validation size of 20%.
# # Split data into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# # Split training data into training and validation sets
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)
# A RandomForestClassifier model is created and trained using the fit method with the training data.
# # Create a random forest classifier
# clf = RandomForestClassifier()
#
# # Train the model using the training set
# clf.fit(X_train, y_train)
# The trained model is used to make predictions on the validation set using the predict method. The accuracy_score function is used to calculate the accuracy of the model by comparing its predictions to the true values in the validation set.
# # Make predictions on the validation set
# y_pred = clf.predict(X_val)
#
# # Calculate the accuracy of the model
# accuracy = accuracy_score(y_val, y_pred)
#
# # Print the accuracy
# print(f'Validation accuracy: {accuracy:.2f}')</small>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
